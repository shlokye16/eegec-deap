# %% [markdown]
# # 02_features.ipynb — Feature Extraction and Validation
# **Inputs:** `results/X_eeg.npy`, `results/X_peripheral.npy`
#
# **Outputs:** `results/X_features.npy` (1280, 131), `results/X_peripheral_features.npy` (1280, 8), `results/feature_names.npy`

# %%
import sys
sys.path.insert(0, '../src')

import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

from features import (
    extract_trial, extract_all, extract_peripheral,
    feature_names, BANDS, CHANNEL_NAMES, FAA_PAIRS,
    N_FEATURES, N_BP_FEATURES,
)

X_eeg        = np.load('../results/X_eeg.npy')
X_peripheral = np.load('../results/X_peripheral.npy')
print(f'X_eeg: {X_eeg.shape}  |  X_peripheral: {X_peripheral.shape}')
# Out:
# X_eeg: (1280, 32, 7680)  |  X_peripheral: (1280, 8, 7680)

# %% [markdown]
# ## 1. Single-trial sanity check

# %%
trial_features = extract_trial(X_eeg[0])
assert trial_features.shape == (N_FEATURES,)
assert np.isfinite(trial_features).all()
assert np.isfinite(trial_features[:N_BP_FEATURES]).all()

names = feature_names()
assert len(names) == N_FEATURES

bp  = trial_features[:N_BP_FEATURES]
faa = trial_features[N_BP_FEATURES:]

print(f'Feature vector shape: {trial_features.shape}')
print(f'Band-power [{N_BP_FEATURES}]: min={bp.min():.4f}  max={bp.max():.4f}')
print(f'FAA [3]: {faa}')
print()
for i in range(8):
    print(f'  [{i:3d}] {names[i]:<20} = {trial_features[i]:.4f}')
print('  ...')
for i in range(N_BP_FEATURES, N_FEATURES):
    print(f'  [{i:3d}] {names[i]:<30} = {trial_features[i]:.4f}')
# Out:
# Feature vector shape: (131,)
# Band-power [128]: min=-1.2580  max=2.2711
# FAA [3]: [ 0.17704765 -0.02562466  0.03034582]
#
#   [  0] Fp1_theta            = 1.3796
#   [  1] Fp1_alpha            = 1.3577
#   [  2] Fp1_beta             = 1.7541
#   [  3] Fp1_gamma            = -0.2759
#   [  4] AF3_theta            = 1.6595
#   [  5] AF3_alpha            = 1.4876
#   [  6] AF3_beta             = 1.8785
#   [  7] AF3_gamma            = -0.3672
#   ...
#   [128] FAA_Fp1_Fp2                    = 0.1770
#   [129] FAA_AF3_AF4                    = -0.0256
#   [130] FAA_F3_F4                      = 0.0303

# %% [markdown]
# ## 2. Single-subject visual check (s01 — run before full extraction)

# %%
X_s01      = np.array([extract_trial(X_eeg[i]) for i in range(40)])
band_names = list(BANDS.keys())
bp_matrix  = X_s01[:, :N_BP_FEATURES].mean(axis=0).reshape(32, 4)  # (32 elec, 4 bands)

fig, ax = plt.subplots(figsize=(7, 9))
im = ax.imshow(bp_matrix, aspect='auto', cmap='viridis')
ax.set_xticks(range(4)); ax.set_xticklabels(band_names)
ax.set_yticks(range(32)); ax.set_yticklabels(CHANNEL_NAMES, fontsize=7)
ax.set_xlabel('Frequency Band'); ax.set_ylabel('Electrode')
ax.set_title('s01 — Mean band power (32 elec × 4 bands, mean over 40 trials)')
plt.colorbar(im, ax=ax, label='Band power')
plt.tight_layout()
plt.savefig('../results/figures/s01_band_power_heatmap.png', dpi=150)
plt.show()

# %%
faa_s01    = X_s01[:, N_BP_FEATURES:]
faa_labels = [f'FAA {CHANNEL_NAMES[l]}-{CHANNEL_NAMES[r]}' for l, r in FAA_PAIRS]

fig, axes = plt.subplots(1, 3, figsize=(11, 3), sharey=True)
for i, ax in enumerate(axes):
    ax.hist(faa_s01[:, i], bins=15, edgecolor='white', lw=0.4)
    ax.axvline(0, color='red', lw=1, ls='--')
    ax.set_title(faa_labels[i], fontsize=9)
    ax.set_xlabel('log(right) - log(left) alpha')
axes[0].set_ylabel('Count')
fig.suptitle('s01 — FAA distributions (plausible range ~-2 to +2; 0 = symmetric)', fontsize=10)
plt.tight_layout()
plt.savefig('../results/figures/s01_faa_distributions.png', dpi=150)
plt.show()

for i, label in enumerate(faa_labels):
    print(f'  {label}: mean={faa_s01[:,i].mean():.3f}  std={faa_s01[:,i].std():.3f}')
# Out:
#   FAA Fp1-Fp2: mean=0.230  std=0.090
#   FAA AF3-AF4: mean=0.004  std=0.116
#   FAA F3-F4: mean=0.156  std=0.150

# %% [markdown]
# ## 3. Full extraction — all 1280 trials

# %%
print('Extracting EEG features for 1280 trials...')
X_features = extract_all(X_eeg)   # (1280, 131)
print(f'Done. Shape: {X_features.shape}')

assert X_features.shape == (1280, N_FEATURES)
assert not np.isnan(X_features).any()
assert not np.isinf(X_features).any()
print('Validation passed.')
print(f'Band-power: min={X_features[:,:N_BP_FEATURES].min():.4f}  '
      f'max={X_features[:,:N_BP_FEATURES].max():.4f}')
print(f'FAA:        min={X_features[:,N_BP_FEATURES:].min():.4f}  '
      f'max={X_features[:,N_BP_FEATURES:].max():.4f}')
# Out:
# Extracting EEG features for 1280 trials...
# Done. Shape: (1280, 131)
# Validation passed.
# Band-power: min=-1.3925  max=10.9033
# FAA:        min=-3.7308  max=5.0092

# %%
X_peripheral_features = extract_peripheral(X_peripheral)  # (1280, 8)
assert X_peripheral_features.shape == (1280, 8)
assert not np.isnan(X_peripheral_features).any()
assert not np.isinf(X_peripheral_features).any()
print(f'Peripheral features: {X_peripheral_features.shape}  '
      f'range [{X_peripheral_features.min():.2f}, {X_peripheral_features.max():.2f}]')
print('(Large range expected — different physical units; StandardScaler handles in LOSO loop)')
# Out:
# Peripheral features: (1280, 8)  range [-239784.37, 908541.61]
# (Large range expected — different physical units; StandardScaler handles in LOSO loop)

# %% [markdown]
# ## 4. Save

# %%
names = feature_names()
np.save('../results/X_features.npy',            X_features)
np.save('../results/X_peripheral_features.npy', X_peripheral_features)
np.save('../results/feature_names.npy',          np.array(names))

for fname in ['X_features', 'X_peripheral_features', 'feature_names']:
    p = Path(f'../results/{fname}.npy')
    print(f'{p}  ({p.stat().st_size / 1e6:.1f} MB)')
print('\nReady for 03_model.ipynb.')
# Out:
# ../results/X_features.npy  (0.7 MB)
# ../results/X_peripheral_features.npy  (0.1 MB)
# ../results/feature_names.npy  (0.0 MB)
#
# Ready for 03_model.ipynb.

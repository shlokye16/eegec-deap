# %% [markdown]
# # 03_model.ipynb — Model Training and Evaluation
#
# **Purpose:** Single unified LOSO loop across 32 subjects, 3 targets, 3 feature configs, 2 classifiers. Followed by batched null distribution with checkpoint saving.
#
# **Inputs:** `results/X_features.npy`, `results/X_peripheral_features.npy`, `results/y.npy`, `results/subject_ids.npy`
#
# **Outputs:** `results/loso_results.pkl`, `results/importance_agg.pkl`, `results/importance_corr.pkl`, `results/importance_mean_*.npy`, `results/null_results.pkl`
#
# **Settings (finalized after trade-off analysis):**
# - `n_jobs=-3` — all cores minus 2, thermal safety
# - `rf_n_estimators=150` — stable band-level and FAA importance, 25% faster than 200
# - `n_perm_repeats=20` — stable on 40-sample test set after 32-fold averaging
# - `float32` — halves memory bandwidth, no effect on results at this precision
#
# **Run once. Do not re-run unless results are corrupted.**

# %%
import sys
sys.path.insert(0, '../src')

import numpy as np
import pickle
from pathlib import Path

from models import (
    run_loso, aggregate_importance,
    importance_correlation, shuffled_label_null,
    paired_accuracy_tests, fdr_correction,
    apply_fdr_to_correlations,
    TARGETS, BAND_NAMES, CONFIGS, CORR_KEYS,
)

Path('../results').mkdir(exist_ok=True)

X_features            = np.load('../results/X_features.npy').astype(np.float32)
X_peripheral_features = np.load('../results/X_peripheral_features.npy').astype(np.float32)
y                     = np.load('../results/y.npy')
subject_ids           = np.load('../results/subject_ids.npy')

print(f'X_features:            {X_features.shape}  dtype={X_features.dtype}')
print(f'X_peripheral_features: {X_peripheral_features.shape}')
# Out:
# X_features:            (1280, 131)  dtype=float32
# X_peripheral_features: (1280, 8)

# %% [markdown]
# ## 1. LOSO loop
#
# All 32 folds run in parallel. joblib verbose=10 prints fold completion as they finish.
# Expected runtime: 8-15 min depending on hardware.

# %%
results = run_loso(
    X_eeg            = X_features,
    X_peripheral     = X_peripheral_features,
    y                = y,
    subject_ids      = subject_ids,
    n_perm_repeats   = 20,
    rf_n_estimators  = 150,
    n_jobs           = -3,
)
print("LOSO complete.")
# Out:
# LOSO folds:   0%|          | 0/32 [00:00<?, ?fold/s]
# [FLAG] valence: imbalance >65/35 in subjects [3, 4, 6, 12, 17, 23, 25, 26, 27, 28, 29, 31]
# [FLAG] arousal: imbalance >65/35 in subjects [2, 4, 8, 9, 15, 20, 23, 24, 26, 27, 28, 32]
# [FLAG] dominance: imbalance >65/35 in subjects [4, 9, 16, 18, 20, 25, 27, 30, 32]
# LOSO complete.

# %% [markdown]
# ## 2. Accuracy sanity check
#
# Chance = 50%. Below 52% = bug. Published DEAP cross-subject baselines: 55-75%.

# %%
print(f"{'Target':<12} {'Config':<12} {'Model':<6} {'Acc':>6} {'Std':>6} {'F1':>6}")
print('-' * 52)
for target in TARGETS:
    for cfg in CONFIGS:
        for model in ('svm', 'rf'):
            acc = results['metrics'][target][cfg][model]['acc']
            f1  = results['metrics'][target][cfg][model]['f1']
            flag = ' <BUG' if np.mean(acc) < 0.50 else '' 
            print(f"{target:<12} {cfg:<12} {model:<6} "
                  f"{np.mean(acc):>6.3f} {np.std(acc):>6.3f} {np.mean(f1):>6.3f}{flag}")
# Out:
# Target       Config       Model     Acc    Std     F1
# ----------------------------------------------------
# valence      eeg          svm     0.525  0.135  0.392
# valence      eeg          rf      0.491  0.141  0.398 <BUG
# valence      peripheral   svm     0.495  0.117  0.488 <BUG
# valence      peripheral   rf      0.502  0.081  0.488
# valence      combined     svm     0.539  0.134  0.426
# valence      combined     rf      0.541  0.104  0.467
# arousal      eeg          svm     0.504  0.129  0.338
# arousal      eeg          rf      0.521  0.114  0.352
# arousal      peripheral   svm     0.513  0.094  0.558
# arousal      peripheral   rf      0.525  0.079  0.511
# arousal      combined     svm     0.492  0.123  0.383 <BUG
# arousal      combined     rf      0.545  0.120  0.407
# dominance    eeg          svm     0.550  0.167  0.451
# dominance    eeg          rf      0.490  0.146  0.394 <BUG
# dominance    peripheral   svm     0.523  0.119  0.509
# dominance    peripheral   rf      0.526  0.109  0.445
# dominance    combined     svm     0.541  0.146  0.441
# dominance    combined     rf      0.490  0.122  0.433 <BUG

# %%
# Class balance flags
any_flagged = False
for target in TARGETS:
    flagged = results['flagged_folds'][target]
    if flagged:
        print(f"[FLAG] {target}: imbalance >65/35 in subjects {flagged} — use F1 as primary metric for these folds")
        any_flagged = True
if not any_flagged:
    print("No flagged folds — all class ratios within 65/35.")
# Out:
# [FLAG] valence: imbalance >65/35 in subjects [3, 4, 6, 12, 17, 23, 25, 26, 27, 28, 29, 31] — use F1 as primary metric for these folds
# [FLAG] arousal: imbalance >65/35 in subjects [2, 4, 8, 9, 15, 20, 23, 24, 26, 27, 28, 32] — use F1 as primary metric for these folds
# [FLAG] dominance: imbalance >65/35 in subjects [4, 9, 16, 18, 20, 25, 27, 30, 32] — use F1 as primary metric for these folds

# %% [markdown]
# ## 3. Importance aggregation

# %%
importance_agg = aggregate_importance(results['importance_mean'])

# Band-level (primary RQ1 result)
print("Band-level importance (summed across 32 electrodes, averaged across 32 folds):")
print(f"{'Band':<8}", '  '.join(f"{t:>10}" for t in TARGETS))
print('-' * 44)
for b, band in enumerate(BAND_NAMES):
    row = '  '.join(f"{importance_agg[t]['band'][b]:>10.5f}" for t in TARGETS)
    print(f"{band:<8}  {row}")

# Region-level
print("\nRegion-level importance:")
for target in TARGETS:
    print(f"\n  {target}:")
    for region, val in sorted(
        importance_agg[target]['region'].items(), key=lambda x: -x[1]
    ):
        print(f"    {region:<22} {val:.5f}")
# Out:
# Band-level importance (summed across 32 electrodes, averaged across 32 folds):
# Band        valence     arousal   dominance
# --------------------------------------------
# theta        0.00531    -0.01285     0.01359
# alpha        0.01441     0.02070     0.00609
# beta         0.02902     0.01766     0.04090
# gamma        0.01004     0.02309     0.00363
#
# Region-level importance:
#
#   valence:
#     frontal_right          0.01777
#     frontal_left           0.01477
#     occipital_left         0.01176
#     central                0.00863
#     parietal_left          0.00465
#     occipital_right        0.00328
#     temporal_right         0.00125
#     parietal_right         -0.00094
#     temporal_left          -0.00238
#
#   arousal:
#     frontal_right          0.02641
#     parietal_left          0.01418
#     frontal_left           0.00883
#     parietal_right         0.00594
#     temporal_right         0.00512
#     temporal_left          -0.00148
#     central                -0.00199
#     occipital_left         -0.00305
#     occipital_right        -0.00535
#
#   dominance:
#     central                0.01777
#     frontal_right          0.01332
#     parietal_right         0.01180
#     frontal_left           0.01156
#     parietal_left          0.00504
#     occipital_right        0.00500
#     temporal_left          0.00438
#     temporal_right         0.00434
#     occipital_left         -0.00898

# %% [markdown]
# ## 4. Importance correlation (RQ5)

# %%
imp_corr = importance_correlation(results['importance_mean'])

print("Pairwise Spearman importance correlation:")
print(f"{'Pair':<30} {'rho':>6}  {'p-value':>9}")
print('-' * 50)
for key, vals in imp_corr.items():
    print(f"{key:<30} {vals['rho']:>6.3f}  {vals['pvalue']:>9.4f}")

print("\n  Low rho for *_dominance pairs → PAD 3rd dimension supported")
print("  High rho for *_dominance pairs → Russell (1980) circumplex collapse supported")
# Out:
# Pairwise Spearman importance correlation:
# Pair                              rho    p-value
# --------------------------------------------------
# valence_arousal                 0.130     0.1378
# valence_dominance              -0.036     0.6834
# arousal_dominance               0.043     0.6249
#
#   Low rho for *_dominance pairs → PAD 3rd dimension supported
#   High rho for *_dominance pairs → Russell (1980) circumplex collapse supported

# %%
# M6: FDR correction on importance correlation p-values
imp_corr_fdr = apply_fdr_to_correlations(imp_corr, alpha=0.05)

print('Importance correlation with BH-FDR correction (alpha=0.05):')
print(f"{'Pair':<30} {'rho':>6}  {'p_raw':>8}  {'p_fdr':>8}  {'reject':>8}")
print('-' * 70)
for key, vals in imp_corr_fdr.items():
    print(f"{key:<30} {vals['rho']:>6.3f}  {vals['pvalue']:>8.4f}  "
          f"{vals['pvalue_fdr']:>8.4f}  {str(vals['reject']):>8}")
# Out:
# Importance correlation with BH-FDR correction (alpha=0.05):
# Pair                              rho     p_raw     p_fdr    reject
# ----------------------------------------------------------------------
# valence_arousal                 0.130    0.1378    0.4133     False
# valence_dominance              -0.036    0.6834    0.6834     False
# arousal_dominance               0.043    0.6249    0.6834     False

# %% [markdown]
# ## 5. Band ablation summary (RQ1 isolation)

# %%
print("Band ablation accuracy (RF, single band, LOSO mean):")
print(f"{'Band':<8}", '  '.join(f"{t:>10}" for t in TARGETS))
print('-' * 44)
for band in BAND_NAMES:
    row = '  '.join(
        f"{np.mean(results['ablation'][t][band]['acc']):>10.3f}"
        for t in TARGETS
    )
    print(f"{band:<8}  {row}")

print("\nFull model (EEG, RF):")
for target in TARGETS:
    print(f"  {target}: {np.mean(results['metrics'][target]['eeg']['rf']['acc']):.3f}")
# Out:
# Band ablation accuracy (RF, single band, LOSO mean):
# Band        valence     arousal   dominance
# --------------------------------------------
# theta          0.495       0.499       0.512
# alpha          0.504       0.506       0.472
# beta           0.537       0.514       0.520
# gamma          0.543       0.500       0.502
#
# Full model (EEG, RF):
#   valence: 0.491
#   arousal: 0.521
#   dominance: 0.490

# %% [markdown]
# ## 6. Save all LOSO outputs

# %%
with open('../results/loso_results.pkl', 'wb') as f:
    pickle.dump(results, f)

with open('../results/importance_agg.pkl', 'wb') as f:
    pickle.dump(importance_agg, f)

with open('../results/importance_corr.pkl', 'wb') as f:
    pickle.dump(imp_corr, f)

for target in TARGETS:
    np.save(f'../results/importance_mean_{target}.npy',
            results['importance_mean'][target])

print("Saved: loso_results.pkl, importance_agg.pkl, importance_corr.pkl")
print("Saved: importance_mean_{valence,arousal,dominance}.npy")

sizes = {p.name: f"{p.stat().st_size/1e6:.1f} MB"
         for p in Path('../results').glob('*.pkl')}
for name, size in sizes.items():
    print(f"  {name}: {size}")
# Out:
# Saved: loso_results.pkl, importance_agg.pkl, importance_corr.pkl
# Saved: importance_mean_{valence,arousal,dominance}.npy
#   loso_results.pkl: 0.1 MB
#   within_subject.pkl: 0.0 MB
#   importance_corr.pkl: 0.0 MB
#   importance_agg.pkl: 0.0 MB
#   null_results.pkl: 0.0 MB
#   svm_importance.pkl: 0.1 MB

# %%
# M3: Paired Wilcoxon signed-rank tests on LOSO fold accuracy (RQ4)
paired = paired_accuracy_tests(results['fold_acc'])

# M6: FDR correction on paired test p-values
paired_pvals = {k: v['pvalue'] for k, v in paired.items()}
paired_fdr   = fdr_correction(paired_pvals, alpha=0.05)

print('Paired Wilcoxon tests on LOSO fold accuracy (32 fold pairs each):')
print(f"{'Comparison':<45} {'mean_diff':>10} {'p_raw':>8} {'p_fdr':>8} {'sig':>5}")
print('-' * 80)
for key, vals in paired.items():
    fdr_p = paired_fdr[key]['pvalue_fdr']
    sig   = '*' if fdr_p < 0.05 else ''
    print(f"{key:<45} {vals['mean_diff']:>10.4f} {vals['pvalue']:>8.4f} {fdr_p:>8.4f} {sig:>5}")

print('\n* = significant after BH-FDR correction (alpha=0.05)')
print('Positive mean_diff for eeg_vs_peripheral → EEG > peripheral; negative → EEG < peripheral')
print('Positive mean_diff for peripheral_vs_combined → peripheral > combined')
# Out:
# Paired Wilcoxon tests on LOSO fold accuracy (32 fold pairs each):
# Comparison                                     mean_diff    p_raw    p_fdr   sig
# --------------------------------------------------------------------------------
# valence_svm_eeg_vs_peripheral                     0.0305   0.5303   0.8006
# valence_svm_peripheral_vs_combined               -0.0445   0.2451   0.8006
# valence_svm_eeg_vs_combined                      -0.0141   0.5999   0.8006
# valence_rf_eeg_vs_peripheral                     -0.0109   0.8006   0.8006
# valence_rf_peripheral_vs_combined                -0.0383   0.0935   0.8006
# valence_rf_eeg_vs_combined                       -0.0492   0.0385   0.6923
# arousal_svm_eeg_vs_peripheral                    -0.0094   0.6876   0.8006
# arousal_svm_peripheral_vs_combined                0.0211   0.6101   0.8006
# arousal_svm_eeg_vs_combined                       0.0117   0.2936   0.8006
# arousal_rf_eeg_vs_peripheral                     -0.0039   0.7701   0.8006
# arousal_rf_peripheral_vs_combined                -0.0203   0.3384   0.8006
# arousal_rf_eeg_vs_combined                       -0.0242   0.3762   0.8006
# dominance_svm_eeg_vs_peripheral                   0.0266   0.4804   0.8006
# dominance_svm_peripheral_vs_combined             -0.0180   0.5433   0.8006
# dominance_svm_eeg_vs_combined                     0.0086   0.7769   0.8006
# dominance_rf_eeg_vs_peripheral                   -0.0359   0.6266   0.8006
# dominance_rf_peripheral_vs_combined               0.0359   0.2208   0.8006
# dominance_rf_eeg_vs_combined                      0.0000   0.7750   0.8006
#
# * = significant after BH-FDR correction (alpha=0.05)
# Positive mean_diff for eeg_vs_peripheral → EEG > peripheral; negative → EEG < peripheral
# Positive mean_diff for peripheral_vs_combined → peripheral > combined

# %% [markdown]
# ## 7. Null distribution
#
# Batched with checkpoint saving to `results/null_checkpoints/`.
# Safe to interrupt — resumes from last completed batch on rerun.
#
# Settings: 100 permutations, batch_size=10, 100 trees, 10 perm repeats.
# These are already the reduced settings for the null — 100 permutations of
# 32-fold averaging compensates for the looser per-permutation estimates.
#
# Expected runtime: 30-50 min total across 10 batches.

# %%
assert Path('../results/loso_results.pkl').exists(), \
    "Run Section 6 first — LOSO results must be saved before starting null."

# checkpoint_dir='null_checkpoints_v2' — incompatible with old null_checkpoints
# (old format: batch_data['acc'][target] = {config: list};
#  new format: batch_data['acc'][target] = list, EEG-only).
# All other args use new fast defaults: 500 perms, 50 trees, 3 repeats.
null_results = shuffled_label_null(
    X_eeg        = X_features,
    X_peripheral = X_peripheral_features,
    y            = y,
    subject_ids  = subject_ids,
)
print('Null distribution complete.')
# Out:
# Null batches:   0%|          | 0/10 [00:00<?, ?batch/s]
# Batch 1/10: resumed from checkpoint (50 perms).
# Batch 2/10: resumed from checkpoint (50 perms).
# Batch 3/10: resumed from checkpoint (50 perms).
# Batch 4/10: resumed from checkpoint (50 perms).
# Batch 5/10: resumed from checkpoint (50 perms).
# Batch 6/10: resumed from checkpoint (50 perms).
# Batch 7/10: resumed from checkpoint (50 perms).
# Batch 8/10: running 50 permutations...
#   Batch 8:   0%|          | 0/50 [00:00<?, ?perm/s]
#   Checkpoint saved: batch_007.pkl
# Batch 9/10: running 50 permutations...
#   Batch 9:   0%|          | 0/50 [00:00<?, ?perm/s]
#   Checkpoint saved: batch_008.pkl
# Batch 10/10: running 50 permutations...
#   Batch 10:   0%|          | 0/50 [00:00<?, ?perm/s]
#   Checkpoint saved: batch_009.pkl
# Null distribution complete.

# %%
# Observed vs null comparison — EEG RF accuracy and importance correlation
print('Null accuracy (EEG RF, LOSO) — mean | std | p5 | p95 | n_perms:')
for target in TARGETS:
    s   = null_results['accuracy'][target]
    obs = np.mean(results['metrics'][target]['eeg']['rf']['acc'])
    sig = 'ABOVE NULL' if obs > s['p95'] else 'within null'
    print(f"  {target:<12} null={s['mean']:.3f}±{s['std']:.3f} "
          f"p5={s['p5']:.3f} p95={s['p95']:.3f} n={s['n']}  obs={obs:.3f}  → {sig}")

print('\nImportance correlation vs null (rho | null_p5 | null_p95 | n_perms):')
for key in CORR_KEYS:
    s   = null_results['correlation'][key]
    obs = imp_corr[key]['rho']
    above_p95 = 'ABOVE p95' if obs > s['p95'] else ''
    below_p5  = 'BELOW p5'  if obs < s['p5']  else ''
    flag = above_p95 or below_p5 or 'within null'
    print(f"  {key:<30} p5={s['p5']:.3f} p95={s['p95']:.3f} n={s['n']}  obs={obs:.3f}  → {flag}")
# Out:
# Null accuracy (EEG RF, LOSO) — mean | std | p5 | p95 | n_perms:
#   valence      null=0.498±0.023 p5=0.459 p95=0.534 n=500  obs=0.491  → within null
#   arousal      null=0.502±0.017 p5=0.473 p95=0.529 n=500  obs=0.521  → within null
#   dominance    null=0.493±0.020 p5=0.463 p95=0.527 n=500  obs=0.490  → within null
#
# Importance correlation vs null (rho | null_p5 | null_p95 | n_perms):
#   valence_arousal                p5=-0.141 p95=0.142 n=500  obs=0.130  → within null
#   valence_dominance              p5=-0.167 p95=0.118 n=500  obs=-0.036  → within null
#   arousal_dominance              p5=-0.138 p95=0.139 n=500  obs=0.043  → within null

# %%
with open('../results/null_results.pkl', 'wb') as f:
    pickle.dump(null_results, f)

print("Saved: null_results.pkl")
print("All results saved. Ready for 04_results.ipynb.")
# Out:
# Saved: null_results.pkl
# All results saved. Ready for 04_results.ipynb.

# %% [markdown]
# # 01_data.ipynb — Data Loading and Validation
# **Outputs:** `results/X_eeg.npy`, `results/X_peripheral.npy`, `results/y.npy`, `results/subject_ids.npy`

# %%
import sys
sys.path.insert(0, '../src')

import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from scipy.signal import welch

from loader import load_subject, load_all, FS, BASELINE_SAMPLES
from features import CHANNEL_NAMES, BANDS

Path('../results/figures').mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## 1. Single-subject inspection (s01)

# %%
eeg, peripheral, labels = load_subject('../data/s01.dat')

assert eeg.shape == (40, 32, 7680),         f'EEG shape mismatch: {eeg.shape}'
assert peripheral.shape == (40, 8, 7680),   f'Peripheral shape mismatch: {peripheral.shape}'
assert labels.shape == (40, 4),             f'Label shape mismatch: {labels.shape}'
assert not np.isnan(eeg).any()
assert not np.isinf(eeg).any()

print(f'EEG:        {eeg.shape}  range [{eeg.min():.2f}, {eeg.max():.2f}] uV')
print(f'Peripheral: {peripheral.shape}')
print(f'Labels:     {labels.shape}')
print(f'NaN: {np.isnan(eeg).any()}  Inf: {np.isinf(eeg).any()}')
print(f'\nTrial 0 Ch 0 first-10 mean: {eeg[0,0,:10].mean():.4f}  '
      f'last-10 mean: {eeg[0,0,-10:].mean():.4f}')
# Out:
# EEG:        (40, 32, 7680)  range [-93.12, 126.13] uV
# Peripheral: (40, 8, 7680)
# Labels:     (40, 4)
# NaN: False  Inf: False
#
# Trial 0 Ch 0 first-10 mean: -4.6266  last-10 mean: 0.0731

# %%
# Raw EEG trace — first 5 seconds of trial 0, channels 0-3
n_plot = 5 * FS
t = np.arange(n_plot) / FS
fig, axes = plt.subplots(4, 1, figsize=(12, 6), sharex=True)
for i, ax in enumerate(axes):
    ax.plot(t, eeg[0, i, :n_plot], lw=0.8)
    ax.set_ylabel(CHANNEL_NAMES[i], fontsize=9)
    ax.axhline(0, color='gray', lw=0.5, ls='--')
axes[-1].set_xlabel('Time (s)')
fig.suptitle('s01 — Trial 0, Ch 0-3, first 5 s (baseline-corrected)', fontsize=11)
plt.tight_layout()
plt.savefig('../results/figures/raw_eeg_trace.png', dpi=150)
plt.show()

# %%
# PSD with band structure — confirm bands are visible
fig, axes = plt.subplots(2, 2, figsize=(10, 6))
colors = {'theta': 'C0', 'alpha': 'C1', 'beta': 'C2', 'gamma': 'C3'}
for i, ax in enumerate(axes.flat):
    freqs, psd = welch(eeg[0, i], fs=FS, nperseg=256, noverlap=128)
    ax.semilogy(freqs, psd, color='black', lw=0.8)
    for band, (lo, hi) in BANDS.items():
        mask = (freqs >= lo) & (freqs < hi)
        ax.fill_between(freqs[mask], psd[mask], alpha=0.35, color=colors[band], label=band)
    ax.set_title(CHANNEL_NAMES[i], fontsize=9)
    ax.set_xlabel('Hz'); ax.set_ylabel('PSD'); ax.set_xlim(0, 50)
    if i == 0:
        ax.legend(fontsize=7)
fig.suptitle('s01 — Trial 0 PSD with frequency bands', fontsize=11)
plt.tight_layout()
plt.savefig('../results/figures/psd_bands.png', dpi=150)
plt.show()

# %% [markdown]
# ## 2. Load all 32 subjects

# %%
X_eeg, X_peripheral, y, subject_ids = load_all('../data')

assert X_eeg.shape        == (1280, 32, 7680)
assert X_peripheral.shape == (1280, 8,  7680)
assert y.shape            == (1280, 4)
assert subject_ids.shape  == (1280,)

unique, counts = np.unique(subject_ids, return_counts=True)
assert (counts == 40).all()
print(f'Subjects: {len(unique)}  |  Trials per subject: 40 (uniform)')
# Out:
# Loaded 32 subjects | 1280 trials | EEG shape: (1280, 32, 7680)
#      valence: min=0.0  max=9.0  mean=3.47  median=3.1
#      arousal: min=0.0  max=9.0  mean=3.73  median=3.3
#    dominance: min=1.0  max=9.0  mean=5.38  median=5.2
#       liking: min=1.0  max=9.0  mean=5.52  median=6.0
# Subjects: 32  |  Trials per subject: 40 (uniform)

# %%
# Label distributions — valence/arousal medians below scale midpoint is a known DEAP property
dim_names = ['valence', 'arousal', 'dominance', 'liking']
print(f'{"Dimension":<12} {"min":>5} {"max":>5} {"mean":>6} {"median":>7} {"std":>6}')
print('-' * 45)
for i, name in enumerate(dim_names):
    col = y[:, i]
    print(f'{name:<12} {col.min():>5.2f} {col.max():>5.2f} '
          f'{col.mean():>6.2f} {np.median(col):>7.2f} {col.std():>6.2f}')

for i, name in enumerate(dim_names):
    n_below = (y[:, i] < 1.0).sum()
    if n_below:
        print(f'\n[NOTE] {name}: {n_below} trials with rating < 1.0 (boundary artifact)')
# Out:
# Dimension      min   max   mean  median    std
# ---------------------------------------------
# valence       0.00  9.00   3.47    3.08   2.01
# arousal       0.00  9.00   3.73    3.31   1.98
# dominance     1.00  9.00   5.38    5.24   2.10
# liking        1.00  9.00   5.52    6.05   2.28
#
# [NOTE] valence: 110 trials with rating < 1.0 (boundary artifact)
#
# [NOTE] arousal: 53 trials with rating < 1.0 (boundary artifact)

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 3))
for i, (ax, name) in enumerate(zip(axes, ['valence', 'arousal', 'dominance'])):
    ax.hist(y[:, i], bins=20, edgecolor='white', lw=0.4)
    ax.axvline(np.median(y[:, i]), color='red', lw=1.5, ls='--',
               label=f'median={np.median(y[:,i]):.2f}')
    ax.set_title(name); ax.set_xlabel('Rating (1-9)')
    ax.set_ylabel('Count' if i == 0 else '')
    ax.legend(fontsize=8)
fig.suptitle('Label distributions — 1280 trials', fontsize=10)
plt.tight_layout()
plt.savefig('../results/figures/label_distributions.png', dpi=150)
plt.show()

# %% [markdown]
# ## 3. Save

# %%
np.save('../results/X_eeg.npy',        X_eeg)
np.save('../results/X_peripheral.npy', X_peripheral)
np.save('../results/y.npy',            y)
np.save('../results/subject_ids.npy',  subject_ids)

for name in ['X_eeg', 'X_peripheral', 'y', 'subject_ids']:
    p = Path(f'../results/{name}.npy')
    print(f'{p}  ({p.stat().st_size / 1e6:.1f} MB)')
# Out:
# ../results/X_eeg.npy  (2516.6 MB)
# ../results/X_peripheral.npy  (629.1 MB)
# ../results/y.npy  (0.0 MB)
# ../results/subject_ids.npy  (0.0 MB)
